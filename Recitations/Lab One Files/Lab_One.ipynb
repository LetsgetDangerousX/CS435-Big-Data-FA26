# %% [markdown]
# # Lab One CS 435

# %% [markdown]
# ![image.png](attachment:ccf93e36-9d36-4d55-b2db-89c74122a6ed.png)

# %% [markdown]
# ![image.png](attachment:6330e4d6-af8c-450b-a638-f65c81098846.png)

# %% [markdown]
# ![image.png](attachment:85f1bbd0-f480-4d52-8057-d20d55285f4e.png)

# %% [markdown]
# ![image.png](attachment:0429580d-0819-40c0-b34e-766e352363aa.png)

# %% [markdown]
# ![image.png](attachment:6a884d23-7831-4dc4-82c1-8a0a40245e0a.png)

# %% [markdown]
# ![image.png](attachment:31540443-24e8-4447-8b4f-2dab5f11680b.png)

# %% [markdown]
# ![image.png](attachment:c6524c5e-bccb-45ff-9ba8-37c9d76a7be6.png)

# %% [markdown]
# ![image.png](attachment:98fc4fdc-be6d-48fb-94c3-ac82303a025f.png)

# %% [markdown]
# ![image.png](attachment:d40c9127-cff9-4787-ba79-a53dedf50890.png)

# %% [markdown]
# ![image.png](attachment:be0b3582-8089-45f2-b51c-3decbe2d41eb.png)

# %% [markdown]
# ![image.png](attachment:15a31c86-a1a5-4911-bfc6-98c01d8a257a.png)

# %% [markdown]
# ![image.png](attachment:c98681cc-c7df-4757-b52a-c0c7a267fda0.png)
