# %% [markdown]
# My Terminal Work

# %% [markdown]
# ![image.png](attachment:1f6cb8d8-fe89-4d24-9f92-4664bc189816.png)

# %% [markdown]
# ![image.png](attachment:784b9cd1-27e5-4942-9000-6ec7a8f6ba2c.png)
